# %%
# BASE
# ------------------------------------------------------
import pandas as pd  
import numpy as np

# DATA VISUALIZATION
# ------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
holidays = pd.read_csv('holidays_events.csv')
oil = pd.read_csv('oil.csv')
sample_submission = pd.read_csv('sample_submission.csv')
stores = pd.read_csv('stores.csv')
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
transactions = pd.read_csv('transactions.csv')

# %% [markdown]
# # Data Cleaning

# %%
def oil_cleaning (data):
    # I will fill the Nan Values with linear interpolation
    data["date"] = pd.to_datetime(data.date)
    
    # Resample
    data = data.set_index("date").dcoilwtico.resample("D").sum().reset_index()
    
    # Interpolate
    data["dcoilwtico"] = np.where(data["dcoilwtico"] == 0, np.nan, data["dcoilwtico"])
    data["dcoilwtico_interpolated"] =data.dcoilwtico.interpolate()
    
    # Fill the Nan value with real value
    data['dcoilwtico_interpolated']=data['dcoilwtico_interpolated'].fillna(93.12)

    # Round the interpolated
    data['dcoilwtico_interpolated']= round(data['dcoilwtico_interpolated'],2)

    # Drop dcoilwtico column and rename dcoilwtico_interpolated
    data= data.drop(['dcoilwtico'], axis=1)
    data.rename(columns={'dcoilwtico_interpolated': 'oil_price'}, inplace=True)
    return data

# %%
oil = oil_cleaning (oil)
oil
# Out:
#            date  oil_price
# 0    2013-01-01      93.12
# 1    2013-01-02      93.14
# 2    2013-01-03      92.97
# 3    2013-01-04      93.12
# 4    2013-01-05      93.15
# ...         ...        ...
# 1699 2017-08-27      46.82
# 1700 2017-08-28      46.40
# 1701 2017-08-29      46.46
# 1702 2017-08-30      45.96
# 1703 2017-08-31      47.26
#
# [1704 rows x 2 columns]

# %%
p = oil.melt(id_vars=['date']+list(oil.keys()[2:]), var_name='Legend')
px.line(p.sort_values(["Legend", "date"], ascending = [False, True]), x='date', y='value', color='Legend',title = "Daily Oil Price" )
# Out:
# <div>                            <div id="e11d88cd-c7d5-4ea6-a9af-9e462e86e01c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e11d88cd-c7d5-4ea6-a9af-9e462e86e01c")) {                    Plotly.newPlot(                        "e11d88cd-c7d5-4ea6-a9af-9e462e86e01c",                        [{"hovertemplate":"Legend=oil_price<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"oil_price","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"oil_price","showlegend":true,"x":["2013-01-01T00:00:00","2013-01-02T00:00:00","2013-01-03T00:00:00","2013-01-04T00:00:00","2013-01-05T00:00:00","2013-01-06T00:00:00","2013-01-07T00:00:00","2013-01-08T00:00:00","2013-01-09T00:00:00","2013-01-10T00:00:00","2013-01-11T00:00:00","2013-01-12T00:00:00","2013-01-13T00:00:00","2013-01-14T00:00:00","2013-01-15T00:00:00","2013-01-16T00:00:00","2013-01-17T00:00:00","2013-01-18T00:00:00","2013-01-19T00:00:00","2013-01-20T00:00:00","2013-01-21T00:00:00","2013-01-22T00:00:00","2013-01-23T00:00:00","2013-01-24T00:00:00","2013-01-25T00:00:00","2013-01-26T00:00:00","2013-01-27T00:00:00","2013-01-28T00:00:00","2013-01-29T00:00:00","2013-01-30T00:00:00","2013-01-31T00:00:00","2013-02-01T00:00:00","2013-02-02T00:00:00","2013-02-03T00:00:00","2013-02-04T00:00:00","2013-02-05T00:00:00","2013-02-06T00:00:00","2013-02-07T00:00:00","2013-02-08T00:00:00","2013-02-09T00:00:00","2013-02-10T00:00:00","2013-02-11T00:00:00","2013-02-12T00:00:00","2013-02-13T00:00:00","2013-02-14T00:00:00","2013-02-15T00:00:00","2013-02-16T00:00:00","2013-02-17T00:00:00","2013-02-18T00:00:00","2013-02-19T00:00:00","2013-02-20T00:00:00","2013-02-21T00:00:00","2013-02-22T00:00:00","2013-02-23T00:00:00","2013-02-24T00:00:00","2013-02-25T00:00:00","2013-02-26T00:00:00","2013-02-27T00:00:00","2013-02-28T00:00:00","2013-03-01T00:00:00","2013-03-02T00:00:00","2013-03-03T00:00:00","2013-03-04T00:00:00","2013-03-05T00:00:00","2013-03-06T00:00:00","2013-03-07T00:00:00","2013-03-08T00:00:00","2013-03-09T00:00:00","2013-03-10T00:00:00","2013-03-11T00:00:00","2013-03-12T00:00:00","2013-03-13T00:00:00","2013-03-14T00:00:00","2013-03-15T00:00:00","2013-03-16T00:00:00","2013-03-17T00:00:00","2013-03-18T00:00:00","2013-03-19T00:00:00","2013-03-20T00:00:00","2013-03-21T00:00:00","2013-03-22T00:00:00","2013-03-23T00:00:00","2013-03-24T00:00:00","2013-03-25T00:00:00","2013-03-26T00:00:00","2013-03-27T00:00:00","2013-03-28T00:00:00","2013-03-29T00:00:00","2013-03-30T00:00:00","2013-03-31T00:00:00","2013-04-01T00:00:00","2013-04-02T00:00:00","2013-04-03T00:00:00","2013-04-04T00:00:00","2013-04-05T00:00:00","2013-04-06T00:00:00","2013-04-07T00:00:00","2013-04-08T00:00:00","2013-04-09T00:00:00","2013-04-10T00:00:00","2013-04-11T00:00:00","2013-04-12T00:00:00","2013-04-13T00:00:00","2013-04-14T00:00:00","2013-04-15T00:00:00","2013-04-16T00:00:00","2013-04-17T00:00:00","2013-04-18T00:00:00","2013-04-19T00:00:00","2013-04-20T00:00:00","2013-04-21T00:00:00","2013-04-22T00:00:00","2013-04-23T00:00:00","2013-04-24T00:00:00","2013-04-25T00:00:00","2013-04-26T00:00:00","2013-04-27T00:00:00","2013-04-28T00:00:00","2013-04-29T00:00:00","2013-04-30T00:00:00","2013-05-01T00:00:00","2013-05-02T00:00:00","2013-05-03T00:00:00","2013-05-04T00:00:00","2013-05-05T00:00:00","2013-05-06T00:00:00","2013-05-07T00:00:00","2013-05-08T00:00:00","2013-05-09T00:00:00","2013-05-10T00:00:00","2013-05-11T00:00:00","2013-05-12T00:00:00","2013-05-13T00:00:00","2013-05-14T00:00:00","2013-05-15T00:00:00","2013-05-16T00:00:00","2013-05-17T00:00:00","2013-05-18T00:00:00","2013-05-19T00:00:00","2013-05-20T00:00:00","2013-05-21T00:00:00","2013-05-22T00:00:00","2013-05-23T00:00:00","2013-05-24T00:00:00","2013-05-25T00:00:00","2013-05-26T00:00:00","2013-05-27T00:00:00","20 ...

# %%
oil.isna().sum()
# Out:
# date         0
# oil_price    0
# dtype: int64

# %% [markdown]
# #  EDA and Data Wrangling

# %%
# From object to datetime
train['date'] = pd.to_datetime(train['date'], errors='coerce')
transactions['date'] = pd.to_datetime(transactions['date'], errors='coerce')
holidays['date'] = pd.to_datetime(holidays['date'], errors='coerce')
test['date'] = pd.to_datetime(test['date'], errors='coerce')

# %%
def merge_data(data):
    # add store information
    data1 = pd.merge(data, stores, how='left', on='store_nbr')

    # add oil pirce information (Remenber to use the mean of the oil price bc if we do the sum when i groupby, I won´t have the real price)
    data2 = pd.merge(data1, oil, how='left', on='date')

    # add transactions (Should be NaN values I will fill with 0, bc there are days where stores were not open)
    # Use the mean in this column too
    model_train = pd.merge(data2, transactions, how='left', on=['date','store_nbr'])
    model_train['transactions']= model_train['transactions'].fillna(0)
    model_train['city'] = model_train['city'].str.lower()
    
    #Let´s work with holidays
    
    # overlapping holidays
    date_count = holidays.groupby("date")[["date"]].count()
    filt = date_count["date"] > 1
    filt  = holidays["date"].isin(date_count.loc[filt].index)
    holidays.loc[filt].head(100)
    
    # Merge data 
    model_train = pd.merge(model_train, holidays, how="left", on="date")
    
    # holiday dataframe requires a bit more filtering so that the correct regions and dates get the correct holidays
    filt = ((model_train["locale"].isin(["Local", "Regional"])) &
    ((model_train["locale_name"] != model_train["city"]) | (model_train["locale_name"] != model_train["state"])))
    
    model_train.rename(columns={"type_x":"shop_type","type_y": "holiday_type", "locale":"holiday_locale"}, inplace=True)
    
    # dropping duplicate id's created by multiple holidays being on the same day
    # for example a location has local holiday and there is a national holiday at the same time
    model_train = model_train.sort_values(["id","holiday_type"]).drop_duplicates("id").reset_index(drop=True)
    
    # filling null holiday spots with normal weekdays
    model_train['holiday_type'] = model_train['holiday_type'].fillna('Work Day')
    
    model_train= model_train.drop(['holiday_locale','locale_name','description','transferred'], axis=1)
    return model_train

# %%
model_train = merge_data(train)

# %%
# model_train[model_train['store_nbr'] == 25]

# %%
# a = train[train['store_nbr']== 1]
# a = a.groupby(["date"]).sales.sum().reset_index()
# a

# %%
# b = test[test['store_nbr']== 1]
# b = b.groupby(["date"]).sum(['sales','onpromotion'])
# b

# %%
# b.groupby(["date"]).onpromotion.sum().reset_index()

# %%
# temp = pd.merge(train.groupby(["date", "store_nbr"]).sales.sum().reset_index(), transactions, how = "left")

# %%
model_train
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state shop_type  cluster  oil_price  \
# 0                  0  quito  Pichincha         D       13      93.12
# 1                  0  quito  Pichincha         D       13      93.12
# 2                  0  quito  Pichincha         D       13      93.12
# 3                  0  quito  Pichincha         D       13      93.12
# 4                  0  quito  Pichincha         D       13      93.12
# ...              ...    ...        ...       ...      ...        ...
# 3000883            0  quito  Pichincha         B        6      47.57
# 3000884            1  quito  Pichincha         B        6      47.57
# 3000885          148  quito  Pichincha         B        6      47.57
# 3000886            8  quito  Pichincha         B        6      47.57
# 3000887            0  quito  Pichincha         B        6      47.57
#
#          transactions holiday_type
# 0                 0.0      Holiday
# 1                 0.0      Holiday
# 2                 0.0      Holiday
# 3                 0.0      Holiday
# 4                 0.0      Holiday
# ...               ...          ...
# 3000883        2155.0      Holiday
# 3000884        2155.0      Holiday
# 3000885        2155.0      Holiday
# 3000886        2155.0      Holiday
# 3000887        2155.0      Holiday
#
# [3000888 rows x 13 columns]

# %% [markdown]
# # Web Scraping

# %%
# 1. import libraries
from bs4 import BeautifulSoup
import requests

# %%
# 2. url: we start with the 'second' page. Show that you can start whenever you want
url ='https://population-hub.com/en/ec/list-of-cities-in-ecuador-by-population.html'

# %%
# 3. download html with a get request
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
# 4.1. parse html (create the 'soup')
soup = BeautifulSoup(response.content, "html.parser")

# %%
# 4.2. check that the html code looks like it should
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>List of cities in Ecuador by population for 2023 | Cities of Ecuador</title>
# <meta content="List of cities in Ecuador by population for 2023 ⚡ - 【Population HUB】." name="description">
# <meta content="List of cities in Ecuador" name="keywords">
# <link href="https://population-hub.com/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto&amp;display=swap" rel="stylesheet"/>
# <link href="https://population-hub.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="https://population-hub.com/jquery.min.js"></script>
# <script src="https://population-hub.com/bootstrap.min.js"></script>
# <link href="https://population-hub.com/en/ec/list-of-cities-in-ecuador-by-population.html" rel="canonical">
# <link href="https://population-hub.com/ru/ec/list-of-cities-in-ecuador-by-population.html" hreflang="ru" rel="alternate"/>
# <link href="https://population-hub.com/en/ec/list-of-cities-in-ecuador-by-population.html" hreflang="en" rel="alternate"/>
# <link href="https://population-hub.com/ua/ec/list-of-cities-in-ecuador-by-population.html" hreflang="uk" rel="alternate"/>
# <meta content="index,follow" name="robots"/>
# <meta content="List of cities in Ecuador by population for 2023 | Cities of Ecuador" property="og:title"/>
# <meta content="List of cities in Ecuador by population for 2023 ⚡ - 【Population HUB】." property="og:description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://population-hub.com/images/flag_of_ecuador.png" property="og:image"/>
# <meta content="https://population-hub.com/en/ec/list-of-cities-in-ecuador-by-population.html" property="og:url"/>
# <meta content="Population HUB" property="og:site_name"/>
# <base href="https://population-hub.com/en/ec/list-of-cities-in-ecuador-by-population.html"/>
# <style type="text/css">body {font-family: Roboto; background-color: #34515f}.fixed-top {background-color: #082935}#breadcrumbs li+li:before {padding: 0 .5rem 0; content: "\203A";color: #eee}#breadcrumbs a.nav-link {display: inline-block}#breadcrumbs span.nav-link {display: inline-block}.nav-link.disabled {color: #e4ff07}a {color: #c8f7ff}a:hover {color: #e4ff07}.nav-pills .nav-link.active {background-color: #082935}.nav-link.active:hover: {background-color: #082935}.nav-link.active:hover:before {padding: 0 .5rem 0; content: "\203A"}.nav-link.hype:hover {color: #f1f1f1}.nav-link.hype:hover:before {padding: 0 .5rem 0; content: "\203A"}section {border-radius: .25rem; padding: 10px 10px 0px 10px; margin-bottom: 20px}footer p {margin: 0; padding: 10px 0}h1 {font-size: 1.8rem}h2 {font-size: 1.3rem}h3 {font-size: 1rem}h3 a, h3 a:hover {color: #082935}.container.links {background-color: #082935; padding: 10px; border-radius: .25rem}.card {border: 0}.card-body {padding: .5rem}.card-body a, card-body a:hover {color: #2F80ED}.card-header {margin: 0; border: 0; background-color: #e6eff3}.card-link, .card-link:hover {color: #000}#accordion {display: inline-block; width: 100%}.right-ads-block {border-bottom: 1px solid #eee; margin-bottom: 10px}.right-ads-block h3 {color: #e4ff07}.right-ads-block p {color: #eee; margin: 0; padding: 5px 0}.flag {color: #eee; display: block; padding: 5px 0}.target-info {display: block; margin: 0 auto; text-align: center}.year {color: #eee}.navbar-brand {color: #eee}.hub {padding: 5px; background-color: #eee; border-radius: 5px; color: #082935; font-weight: 600}.p-info {background-color: #34515f; color: #e4ff07; padding: 4px; border-radius: 5px}.c-content {background-color: #082935; padding: 15px 0; margin-bottom: 10px}.r-1 {margin-top: 56px; padding: 10px 0}.htwo{color: #eee;margin-top: 15px}footer{color: #eee}.useful-links a, .useful-links a:hover{color: #135fbd}.useful-links p {font-size: 1rem}.table-responsive a, .table-responsive a:hover {color:#135fbd}h2.aside{color: #eee;padding: 15px 0 0 15px;border-top: 1px solid #eee;border-left: 1px solid #eee}section{background-color:#e6eff3}.letter{display:inline}.ln{display: inline-block;padding:0 0.5em;line-height: 1.25rem;font-size: 1.1rem;}.ln.not-active{color: #e4ff0f;text-decoration: underline}
#
# .stickblock {width: 100%; position: fixed; padding: 0; background-color: rgba(255,255,255,0.95); bottom: 0; left: 0; text-align: center; z-index: 99999; border-top: 1px solid #f5f5f5;}
# .adclose {position: absolute; right: 10px; top: -23px; padding: 5px 0; font-size: 24px; cursor: pointer; z-index: 99;}
#
# .ads-1 {max-width: 728px!important}
#
# #ads img {max-width: 100%; display: block; margin: 0 auto; padding-bottom: 10px}
# </style>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-165565489-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-165565489-1');
# </script>
# <script async="" data-ad-client="ca-pub-5726896040656039" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script async="" src="//gyqywg.com/fhn7l1/912ivlp0m30y8qh867/vuq876/kypf2.php"></script>
# </link></meta></meta></head>
# <body itemscope="itemscope" itemtype="http://schema.org/WebPageElement">
# <nav class="navbar navbar-expand-sm fixed-top" itemscope="itemscope" itemtype="http://www.schema.org/SiteNavigationElement">
# <div class="container">
# <a class="navbar-brand" href="https://population-hub.com/">Population <span class="hub">HUB</span></a>
# <button class="navbar-toggler" data-target="#collapsibleNavbar" data-toggle="collapse" type="button">
# <span class="navbar-toggler-icon"></span>
# </button>
# <div class="collapse navbar-collapse" id="collapsibleNavbar">
# <ul class="navbar-nav">
# <li class="nav-item" itemprop="name">
# <a class="nav-link" href="https://population-hub.com/en/list-of-countries-by-population.html" itemprop="url">Countries</a>
# </li>
# <li class="nav-item" itemprop="name">
# <a class="nav-link" href="https://population-hub.com/en/list-of-cities-by-population.html" itemprop="url">Cities</a>
# </li>
# <li class="nav-item" itemprop="name">
# <a class="nav-link" href="https://population-hub.com/en/list-of-capitals-by-population.html" itemprop="url">Capitals</a>
# </li>
# <li class="nav-item" itemprop="name">
# <span class="nav-link">
# <img alt="en icon" src="https://population-hub.com/en.png"/>
# </span>
# </li>
# <li class="nav-item" itemprop="name">
# <a class="nav-link" href="https://population-hub.com/ru/ec/list-of-cities-in-ecuador-by-population.html" itemprop="url">
# <img alt="ru icon" src="https://population-hub.com/ru.png"/>
# </a>
# </li>
# <li class="nav-item" itemprop="name">
# <a class="nav-link" href="https://population-hub.com/ua/ec/list-of-cities-in-ecuador-by-population.html" itemprop="url">
# <img alt="ua icon" src="https://population-hub.com/ua.png"/>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </nav>
# <div class="container r-1">
# <div class="ads-1">
# <!--<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  PH ads 1 [EN] -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5726896040656039" data-ad-slot="9282340601" style="display:inline-block;width:100%;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script> </div>
# </div>
# <div class="container">
# <ul class="nav" id="breadcrumbs" itemscope="" itemtype="https://schema.org/BreadcrumbList">
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a class="nav-link" href="https://population-hub.com/en/population-of-earth.html" itemprop="item">
# <span itemprop="name">Earth population</span>
# </a>
# <meta content="1" itemprop="position"/>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <a class="nav-link" href="https://population-hub.com/en/ec/population-of-ecuador.html" itemprop="item">
# <span itemprop="name">Population of Ecuador</span>
# </a>
# <meta content="2" itemprop="position"/>
# </li>
# <li itemprop="itemListElement" itemscope="" itemtype="https://schema.org/ListItem">
# <span class="nav-link disabled" itemprop="name">List of cities in Ecuador</span>
# <meta content="3" itemprop="position"/>
# </li>
# </ul>
# </div>
# <div class="container">
# <div class="row">
# <section class="col-sm-8" style="background-color: #e6eff3">
# <h1 itemprop="headline">List of cities in Ecuador by population</h1>
# <p class="text-justify" itemprop="text">The list consists of the largest cities Ecuador <img alt="Flag of  Ecuador" height="20px" src="https://population-hub.com/images/flag_of_ecuador.png" title="Flag of  Ecuador"/>. In total, there are 31 cities in Ecuador. The largest city is <strong>Guayaquil</strong> with a population of <span class="p-info">2 278 691</span>. The total population of Ecuador is 17449210 people - 0.22% of the total population of the Earth.</p>
# <ins class="adsbygoogle" data-ad-client="ca-pub-5726896040656039" data-ad-format="autorelaxed" data-ad-slot="1696208249" data-matched-content-columns-num="4" data-matched-content-rows-num="1" data-matched-content-ui-type="image_stacked" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script> <input class="form-control" id="myInput" placeholder="City search.." type="text"/>
# <div class="table-responsive">
# <table class="table table-bordered">
# <thead>
# <tr>
# <th>#</th>
# <th>Name, city</th>
# <th>Population</th>
# </tr>
# </thead>
# <tbody id="myTable">
# <tr><th>1</th><td><a href="https://population-hub.com/en/ec/population-of-guayaquil-8020.html">Guayaquil</a></td><td>2 278 691</td></tr><tr><th>2</th><td><a href="https://population-hub.com/en/ec/population-of-quito-8021.html">Quito</a></td><td>1 607 734</td></tr><tr><th>3</th><td><a href="https://population-hub.com/en/ec/population-of-cuenca-8022.html">Cuenca</a></td><td>329 928</td></tr><tr><th>4</th><td><a href="https://population-hub.com/en/ec/population-of-santo-domingo-8023.html">Santo Domingo</a></td><td>270 875</td></tr><tr><th>5</th><td><a href="https://population-hub.com/en/ec/population-of-machala-8024.html">Machala</a></td><td>231 260</td></tr><tr><th>6</th><td><a href="https://population-hub.com/en/ec/population-of-duran-8025.html">Duran</a></td><td>230 839</td></tr><tr><th>7</th><td><a href="https://population-hub.com/en/ec/population-of-manta-8026.html">Manta</a></td><td>217 553</td></tr><tr><th>8</th><td><a href="https://population-hub.com/en/ec/population-of-portoviejo-8027.html">Portoviejo</a></td><td>206 682</td></tr><tr><th>9</th><td><a href="https://population-hub.com/en/ec/population-of-loja-8028.html">Loja</a></td><td>170 280</td></tr><tr><th>10</th><td><a href="https://population-hub.com/en/ec/population-of-ambato-8029.html">Ambato</a></td><td>165 185</td></tr><tr><th>11</th><td><a href="https://population-hub.com/en/ec/population-of-esmeraldas-8030.html">Esmeraldas</a></td><td>154 035</td></tr><tr><th>12</th><td><a href="https://population-hub.com/en/ec/population-of-quevedo-8031.html">Quevedo</a></td><td>150 827</td></tr><tr><th>13</th><td><a href="https://population-hub.com/en/ec/population-of-riobamba-8032.html">Riobamba</a></td><td>146 324</td></tr><tr><th>14</th><td><a href="https://population-hub.com/en/ec/population-of-milagro-8033.html">Milagro</a></td><td>133 508</td></tr><tr><th>15</th><td><a href="https://population-hub.com/en/ec/population-of-ibarra-8034.html">Ibarra</a></td><td>131 856</td></tr><tr><th>16</th><td><a href="https://population-hub.com/en/ec/population-of-la-libertad-8035.html">La Libertad</a></td><td>95 942</td></tr><tr><th>17</th><td><a href="https://population-hub.com/en/ec/population-of-babaoyo-8036.html">Babaoyo</a></td><td>90 191</td></tr><tr><th>18</th><td><a href="https://population-hub.com/en/ec/population-of-sangolki-8037.html">Sangolki</a></td><td>75 080</td></tr><tr><th>19</th><td><a href="https://population-hub.com/en/ec/population-of-daul-8038.html">Daul</a></td><td>65 145</td></tr><tr><th>20</th><td><a href="https://population-hub.com/en/ec/population-of-latacunga-8039.html">Latacunga</a></td><td>63 842</td></tr><tr><th>21</th><td><a href="https://population-hub.com/en/ec/population-of-tulcan-8040.html">tulcán</a></td><td>60 403</td></tr><tr><th>22</th><td><a href="https://population-hub.com/en/ec/population-of-chong-8041.html">Chong</a></td><td>52 810</td></tr><tr><th>23</th><td><a href="https://population-hub.com/en/ec/population-of-pasach-8042.html">pasach</a></td><td>52 673</td></tr><tr><th>24</th><td><a href="https://population-hub.com/en/ec/population-of-santa-rosa-8043.html">Santa Rosa</a></td><td>48 929</td></tr><tr><th>25</th><td><a href="https://population-hub.com/en/ec/population-of-nueva-loja-8044.html">Nueva Loja</a></td><td>48 562</td></tr><tr><th>26</th><td><a href="https://population-hub.com/en/ec/population-of-uakilyas-8045.html">Uakilyas</a></td><td>47 706</td></tr><tr><th>27</th><td><a href="https://population-hub.com/en/ec/population-of-el-carmen-8046.html">El Carmen</a></td><td>46 358</td></tr><tr><th>28</th><td><a href="https://population-hub.com/en/ec/population-of-montecristi-8047.html">Montecristi</a></td><td>46 312</td></tr><tr><th>29</th><td><a href="https://population-hub.com/en/ec/population-of-samborondon-8048.html">Samborondon</a></td><td>42 637</td></tr><tr><th>30</th><td><a href="https://population-hub.com/en/ec/population-of-francisco-de-orellana-8049.html">Francisco de Orellana</a></td><td>40 730</td></tr><tr><th>31</th><td><a  ...
# </table>
# </div>
# <script>
# $(document).ready(function(){
# $("#myInput").on("keyup", function() {
# var value = $(this).val().toLowerCase();
# $("#myTable tr").filter(function() {
# $(this).toggle($(this).text().toLowerCase().indexOf(value) > -1)
# });
# });
# });
# </script>
# <div data-la-block="6d7e4c1a-1900-42fb-aad7-0911addd8756"></div> <p><strong>Population HUB</strong> - this is an accessible statistics of the population of the country, city and any other region. Fast site work and constantly updated data. Thank you for choosing the Population HUB.</p>
# <div id="accordion" itemscope="itemscope" itemtype="https://schema.org/FAQPage">
# <div class="h4">FAQ</div>
# <div class="card" itemprop="mainEntity" itemscope="itemscope" itemtype="https://schema.org/Question">
# <div class="card-header" itemprop="name">
# <a class="card-link" data-toggle="collapse" href="#collapseOne">⚡ How many cities in Ecuador?</a>
# </div>
# <div class="collapse" data-parent="#accordion" id="collapseOne" itemprop="acceptedAnswer" itemscope="itemscope" itemtype="https://schema.org/Answer">
# <div class="card-body" itemprop="text">In total, Ecuador has 31 cities with a total population of 17449210 people for 2023.</div>
# </div>
# </div>
# <div class="card" itemprop="mainEntity" itemscope="itemscope" itemtype="https://schema.org/Question">
# <div class="card-header" itemprop="name">
# <a class="card-link" data-toggle="collapse" href="#collapseTwo">⚡ What is the largest city in Ecuador by population?</a>
# </div>
# <div class="collapse" data-parent="#accordion" id="collapseTwo" itemprop="acceptedAnswer" itemscope="itemscope" itemtype="https://schema.org/Answer">
# <div class="card-body" itemprop="text">The largest population in Guayaquil is 2 278 691.</div>
# </div>
# </div>
# </div>
# <p></p>
# </section>
# <aside class="col-sm-4" itemscope="itemscope" itemtype="http://schema.org/WPSideBar">
# <h2 class="aside">Lists of cities by country</h2>
# <ul class="nav nav-pills flex-column">
# <li class="nav-item">
# <a class="nav-link hype" href="https://population-hub.com/en/nl/list-of-cities-in-netherlands-by-population.html" itemprop="url"><span itemprop="name">List of cities Netherlands</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link hype" href="https://population-hub.com/en/sy/list-of-cities-in-syria-by-population.html" itemprop="url"><span itemprop="name">List of cities Syria</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link hype" href="https://population-hub.com/en/td/list-of-cities-in-chad-by-population.html" itemprop="url"><span itemprop="name">List of cities Chad</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link hype" href="https://population-hub.com/en/so/list-of-cities-in-somalia-by-population.html" itemprop="url"><span itemprop="name">List of cities Somalia</span></a>
# </li>
# <li class="nav-item">
# <a class="nav-link hype" href="https://population-hub.com/en/kh/list-of-cities-in-cambodia-by-population.html" itemprop="url"><span itemprop="name">List of cities Cambodia</span></a>
# </li>
# </ul>
# <div class="ads-3">
# <!--<script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  PH ads 3 [EN] -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5726896040656039" data-ad-format="auto" data-ad-slot="2520178058" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script> </div>
# </aside>
# </div>
# </div>
# <div class="container htwo">
# <h2>Recently interested in the population</h2>
# </div>
# <div class="container links">
# <div class="row">
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/us/population-of-redmond-674.html">Population of Redmond</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/us/population-of-lahaina-1618.html">Population of Lahaina</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/jp/population-of-tokoname-3885.html">Population of Tokoname</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/eg/population-of-el-badrashin-4299.html">Population of El Badrashin</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/tr/population-of-yalova-4678.html">Population of Yalova</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/fr/population-of-besancon-5211.html">Population of Besancon</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/sd/population-of-rabac-6126.html">Population of Rabac</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/ua/population-of-tlumach-6512.html">Population of Tlumach</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/lk/population-of-dzhaela-7461.html">Population of Dzhaela</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/ro/population-of-candara-7726.html">Population of Candara</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/uy/population-of-ciudad-del-plata-10971.html">Population of Ciudad del Plata</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/fj/population-of-vatukoula-11752.html">Population of Vatukoula</a> </div>
# </div>
# </div>
# <div class="container htwo">
# <h2>Interesting pages</h2>
# </div>
# <div class="container links">
# <div class="row">
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/bt/cities-starting-with-letter-c-in-bhutan.html">Cities in Bhutan starting with the letter C</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/pw/cities-starting-with-letter-d-in-palau.html">Cities in Palau starting with the letter D</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/id/cities-starting-with-letter-f-in-indonesia.html">Cities in Indonesia starting with the letter F</a> </div>
# <div class="col-sm-3">
# <a class="nav-link" href="https://population-hub.com/en/st/cities-starting-with-letter-g-in-sao-tome-and-principe.html">Cities in São Tomé and Príncipe starting with the letter G</a> </div>
# </div>
# </div>
# <footer class="container-fluid">
# <div class="container text-center">
# <p>© Population HUB - 2023</p>
# <p>Find out the population in your area!</p>
# </div>
# </footer>
# <div class="stickblock" id="stickblock">
# <!-- PH [FIX] -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5726896040656039" data-ad-slot="1978309428" style="display:inline-block;width:728px;height:90px"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# <span class="adclose" onclick="adClose()">×</span>
# </div>
# <!-- Yandex.Metrika counter -->
# <script type="text/javascript">
#    (function(m,e,t,r,i,k,a){m[i]=m[i]||function(){(m[i].a=m[i].a||[]).push(arguments)};
#    m[i].l=1*new Date();k=e.createElement(t),a=e.getElementsByTagName(t)[0],k.async=1,k.src=r,a.parentNode.insertBefore(k,a)})
#    (window, document, "script", "https://mc.yandex.ru/metrika/tag.js", "ym");
#
#    ym(62558404, "init", {
#         clickmap:true,
#         trackLinks:true,
#         accurateTrackBounce:true
#    });
# </script>
# <!-- /Yandex.Metrika counter -->
# <script>
# function adClose() {
#   var x = document.getElementById("stickblock");
#   if (x.style.display === "none") {
#     x.style.display = "block";
#   } else {
#     x.style.display = "none";
#   }
# }
# </script>
# <script>
# $('#ads').load('https://population-hub.com/ads.php');
# </script>
# </body>
# </html>

# %%
soup.select("#myTable > tr:nth-child(1) > td:nth-child(2)")[0].get_text()
# Out:
# 'Guayaquil'

# %%
soup.select("#myTable > tr:nth-child(1)> td:nth-child(3)")[0].get_text().replace('\xa0',"")
# Out:
# '2278691'

# %%
#initialize empty lists
city = []
population = []
# Define a for lop to make some list
num_iter = 31
for i in range(1,num_iter+1):
    tClist = soup.select("#myTable > tr:nth-child("+str(i)+") > td:nth-child(2)")
    artistlist = soup.select("#myTable > tr:nth-child("+str(i)+") > td:nth-child(3)")
    city.append(tClist[0].get_text())
    population.append(artistlist[0].get_text().replace('\xa0',""))
# each list becomes a column
population_data = pd.DataFrame({"city":city,
                       "population":population
                      })

# %%
def cleaning_population_data(data):
    # Prepare to merge with other data
    data['population']=data['population'].astype(int)
    data['city']=data['city'].str.lower()
    # Add cities which appear in the dataset but not in web scraping
    data= data.append([{'city':'cayambe', 'population':28604},{'city':'guaranda', 'population':23887},{'city':'puyo', 'population':26773},{'city':'playas', 'population':41935}], ignore_index=True)
    # Modify some names
    data['city']= data['city'].replace('uakilyas', 'salinas')
    data['city']= data['city'].replace('la libertad', 'libertad')
    data['city']= data['city'].replace('daul', 'daule')
    data['city']= data['city'].replace('babaoyo', 'babahoyo')
    # Merge with model_train
    model = pd.merge(model_train, data, how='left', on='city')
    return model

# %%
model_train = cleaning_population_data(population_data)
# Out:
# C:\Users\gorka\AppData\Local\Temp\ipykernel_11348\1349901536.py:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
# population_data['population']=population_data['population'].astype(int)
# population_data['city']=population_data['city'].str.lower()

# %%
# # Add cities which appear in the dataset but not in web scraping
# population_data= population_data.append([{'city':'cayambe', 'population':28604},{'city':'guaranda', 'population':23887},{'city':'puyo', 'population':26773},{'city':'playas', 'population':41935}], ignore_index=True)
# # modify some names
# population_data['city']= population_data['city'].replace('uakilyas', 'salinas')
# population_data['city']= population_data['city'].replace('la libertad', 'libertad')
# population_data['city']= population_data['city'].replace('daul', 'daule')
# population_data['city']= population_data['city'].replace('babaoyo', 'babahoyo')

# %%
# population_data.to_csv("population_data.csv", index=False)

# %%
# model_train = pd.merge(model_train, population_data, how='left', on='city')

# %%
model_train
# Out:
#               id       date  store_nbr                      family     sales  \
# 0              0 2013-01-01          1                  AUTOMOTIVE     0.000
# 1              1 2013-01-01          1                   BABY CARE     0.000
# 2              2 2013-01-01          1                      BEAUTY     0.000
# 3              3 2013-01-01          1                   BEVERAGES     0.000
# 4              4 2013-01-01          1                       BOOKS     0.000
# ...          ...        ...        ...                         ...       ...
# 3000883  3000883 2017-08-15          9                     POULTRY   438.133
# 3000884  3000884 2017-08-15          9              PREPARED FOODS   154.553
# 3000885  3000885 2017-08-15          9                     PRODUCE  2419.729
# 3000886  3000886 2017-08-15          9  SCHOOL AND OFFICE SUPPLIES   121.000
# 3000887  3000887 2017-08-15          9                     SEAFOOD    16.000
#
#          onpromotion   city      state shop_type  cluster  oil_price  \
# 0                  0  quito  Pichincha         D       13      93.12
# 1                  0  quito  Pichincha         D       13      93.12
# 2                  0  quito  Pichincha         D       13      93.12
# 3                  0  quito  Pichincha         D       13      93.12
# 4                  0  quito  Pichincha         D       13      93.12
# ...              ...    ...        ...       ...      ...        ...
# 3000883            0  quito  Pichincha         B        6      47.57
# 3000884            1  quito  Pichincha         B        6      47.57
# 3000885          148  quito  Pichincha         B        6      47.57
# 3000886            8  quito  Pichincha         B        6      47.57
# 3000887            0  quito  Pichincha         B        6      47.57
#
#          transactions holiday_type  population
# 0                 0.0      Holiday     1607734
# 1                 0.0      Holiday     1607734
# 2                 0.0      Holiday     1607734
# 3                 0.0      Holiday     1607734
# 4                 0.0      Holiday     1607734
# ...               ...          ...         ...
# 3000883        2155.0      Holiday     1607734
# 3000884        2155.0      Holiday     1607734
# 3000885        2155.0      Holiday     1607734
# 3000886        2155.0      Holiday     1607734
# 3000887        2155.0      Holiday     1607734
#
# [3000888 rows x 14 columns]

# %% [markdown]
# # Prepare for modeling

# %%
# # I will start preparing the table to make the model
# model_train.dtypes
# model_train['store_nbr']= model_train['store_nbr'].astype(object)
# model_train['cluster']= model_train['cluster'].astype(object)
# # Drop id column
# model_train= model_train.drop('id', axis=1)
## Time Related Features
def create_date_features(df):
    df['month'] = df.date.dt.month.astype(object)
    df['day_of_month'] = df.date.dt.day.astype(object)
    df['day_of_year'] = df.date.dt.dayofyear.astype(object)
    df['week_of_year'] = (df.date.dt.isocalendar().week).astype(object)
    df['day_of_week'] = (df.date.dt.dayofweek + 1).astype(object)
    df['year'] = df.date.dt.year.astype(object)
    df["is_wknd"] = (df.date.dt.weekday // 4).astype(object)
    return df

# %%
def create_columns (data):
    # I will start preparing the table to make the model
    data['store_nbr']= data['store_nbr'].astype(object)
    data['cluster']= data['cluster'].astype(object)
    # Drop id column
    data= data.drop('id', axis=1)
    # Time Related features
    data = create_date_features(data)
    data = data.set_index('date')
    return data

# %%
model_train = create_columns (model_train)

# %%
def preparing_data_to_model(data, random_state=None):   
    from sklearn.preprocessing import MinMaxScaler
    from sklearn.preprocessing import OneHotEncoder
    # Split data
    target_col = 'sales'
    X = data.drop(target_col, axis=1)
    y = data[target_col]
    
    # Numerical-Categorical Split
    model_train_num = X.select_dtypes(include = np.number)
    model_train_cat = X.select_dtypes(object)
    
    # Scaling numerical data
    transformer = MinMaxScaler().fit(model_train_num)
    model_train_scaled1 = pd.DataFrame(transformer.transform(model_train_num),columns=model_train_num.columns)

    # Encoding categorical data
    encoder = OneHotEncoder(drop='first').fit(model_train_cat)
    column_names = encoder.get_feature_names_out(model_train_cat.columns)
    model_train_encoded = encoder.transform(model_train_cat).toarray()
    encoded = pd.DataFrame(model_train_encoded, columns =column_names)

    # Concatenate data
    model_train_scaled = pd.concat([model_train_scaled1,encoded],axis=1)
    
    print(model_train_scaled.shape, y.shape, transformer, encoder)
    
    return model_train_scaled, y, transformer, encoder

# %%
#Fit a logistic regression model on the training data.
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
lm = linear_model.LinearRegression()

# %%
def store_regression(data):
    # Split the data by store_id
    store_data = {}
    for store_id in data['store_nbr'].unique():
        store_data[store_id] = data[data['store_nbr'] == store_id]
    
    # Perform linear regression for each store
    regression_results = {}
    for store_id, store_df in store_data.items():
        X = store_df.drop('sales', axis=1)
        y = store_df['sales']
        
        # Prepare the data for modeling
        X_scaled, y, transformer, encoder = preparing_data_to_model(pd.concat([X, y], axis=1))
        
        # Fit the model
        model = linear_model.LinearRegression()
        model.fit(X_scaled, y)
        
        # Calculate RMSE 
        model_pred = model.predict(X_scaled)
        model_rmse = np.sqrt(mean_squared_error(y, model_pred))
        
        # Store the regression results
        regression_results[store_id] = {'model':model,
            'score': model.score(X_scaled, y),
            'RMSE': model_rmse,
            'Predicted':np.round(model_pred[:10],decimals = 1),
            'Real': y[:10],
            'Transformer':transformer,
            'Encoder':encoder                          
        }
    
    return regression_results

# %%
# # Use the 'sample' function to randomly sample 50% of the rows
# X_sampled = model_train.sample(frac=0.05, random_state=42)  # Setting random_state for reproducibility

# # 'X_sampled' now contains 50% of the rows from 'all_films'
# X_sampled.shape

# %%
results = store_regression(model_train)
# Out:
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')
# (55572, 510) (55572,) MinMaxScaler() OneHotEncoder(drop='first')

# %%
results
# Out:
# {1: {'model': LinearRegression(),
#   'score': 0.8150934404039293,
#   'RMSE': 256.63791591017076,
#   'Predicted': array([-283.6, -283.5, -276.6, 1175.4, -290.9,   34. , -278.9,  283.9,
#           267.9, -233.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  10: {'model': LinearRegression(),
#   'score': 0.9058776255156276,
#   'RMSE': 146.4233840550097,
#   'Predicted': array([-214. , -213.2, -218.8,  646.1, -216.7, -118.5, -215.5,  529.8,
#             2.3,    6.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  11: {'model': LinearRegression(),
#   'score': 0.9019403879852435,
#   'RMSE': 425.95375979087055,
#   'Predicted': array([-600.2, -649.4, -603.6, 2898.6, -614.8,  -75.3, -631.7, 1186.3,
#          -209.2, -268.7]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  12: {'model': LinearRegression(),
#   'score': 0.874713807893005,
#   'RMSE': 184.59565342845227,
#   'Predicted': array([-245.7, -250.6, -248.3, 1000.4, -249.9,  -89.9, -241.9,  485.1,
#            31. ,  -87.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  13: {'model': LinearRegression(),
#   'score': 0.8772212096765937,
#   'RMSE': 193.26208135955727,
#   'Predicted': array([-259. , -274. , -276.5,  980.2, -277.3, -121.8, -275.3,  480.5,
#           -27.2, -126.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  14: {'model': LinearRegression(),
#   'score': 0.8747666021134229,
#   'RMSE': 191.33189561897188,
#   'Predicted': array([-275.2, -279.4, -278. ,  645.6, -278.6, -110. , -274.9,  772.9,
#            22.9,  -90. ]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  15: {'model': LinearRegression(),
#   'score': 0.9130251604999796,
#   'RMSE': 160.11672661052373,
#   'Predicted': array([-250.7, -252.3, -250.5,  941.1, -253. , -114.9, -250.5,  586.4,
#             7.4,  -14.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  16: {'model': LinearRegression(),
#   'score': 0.8575901235632036,
#   'RMSE': 199.76804815175527,
#   'Predicted': array([-277. , -282.5, -281.7,  795.2, -282.7,  -84.2, -279.1,  713.4,
#           -44.6,  -73.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  17: {'model': LinearRegression(),
#   'score': 0.8573949676855774,
#   'RMSE': 321.9028835686865,
#   'Predicted': array([-419.2, -425.6, -424. , 1870.3, -424.2, -236.3, -419.8,  550.5,
#           -16.3,  -93.4]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  18: {'model': LinearRegression(),
#   'score': 0.7604627102482463,
#   'RMSE': 302.5231546217113,
#   'Predicted': array([-303.9, -309.5, -302.6, 1265.2, -307.4,  289.4, -297.9,  239.2,
#            56.9, -168.8]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  19: {'model': LinearRegression(),
#   'score': 0.8763602922987659,
#   'RMSE': 232.85297438341905,
#   'Predicted': array([-311.1, -317.6, -317. , 1587.2, -317.6, -166.7, -312.4,  559.7,
#           -86.1,  -90.8]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  2: {'model': LinearRegression(),
#   'score': 0.6028205400609938,
#   'RMSE': 680.3563846532376,
#   'Predicted': array([-500. , -515.6, -510.4, 1828.9, -509.9,   25.8, -497. ,  381.7,
#           270.4, -346.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  20: {'model': LinearRegression(),
#   'score': 0.4652173016293155,
#   'RMSE': 706.5323037462967,
#   'Predicted': array([-169. , -179.9, -181.3, 1239.2, -180.6,  -74. , -171.9,  341.8,
#           -38. ,  -10. ]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  21: {'model': LinearRegression(),
#   'score': 0.5548121019698162,
#   'RMSE': 434.54964523952555,
#   'Predicted': array([-111. , -120.5, -119.8,  847. , -122.1,  -28.6, -120.5,  274.8,
#          -107.5,  -84.2]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  22: {'model': LinearRegression(),
#   'score': 0.5768758429305527,
#   'RMSE': 205.6963990001135,
#   'Predicted': array([-41.8, -43.1, -45. , 355.5, -43.2, -48.8, -40.3, 102.6, -57.8,
#          -44.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  23: {'model': LinearRegression(),
#   'score': 0.8507272779786539,
#   'RMSE': 176.72747353993876,
#   'Predicted': array([-248.1, -250.4, -249.5,  875.9, -250.3,   14.7, -242.2,  291.5,
#           189.3, -147.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  24: {'model': LinearRegression(),
#   'score': 0.7922165196862124,
#   'RMSE': 464.4479442533017,
#   'Predicted': array([-480.3, -486.8, -485.1, 2149. , -480.2,  173.1, -475.9,  510.2,
#           472.7, -357.4]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  25: {'model': LinearRegression(),
#   'score': 0.6658914202714245,
#   'RMSE': 324.36005992355666,
#   'Predicted': array([ -71.4,  -72.7,  -73. , 1590.5,  -73.7,  197.5,  -70.4,  345.4,
#           341.2,   -2.3]),
#   'Real': date
#   2013-01-01      0.000
#   2013-01-01      0.000
#   2013-01-01      2.000
#   2013-01-01    810.000
#   2013-01-01      0.000
#   2013-01-01    180.589
#   2013-01-01      0.000
#   2013-01-01    186.000
#   2013-01-01    143.000
#   2013-01-01     71.090
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  26: {'model': LinearRegression(),
#   'score': 0.5745990493230481,
#   'RMSE': 274.1753969656912,
#   'Predicted': array([-178.5, -182.6, -181.2,  557.1, -183. ,   32.9, -178.6,  223. ,
#            30.3, -119.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  27: {'model': LinearRegression(),
#   'score': 0.8232869237295973,
#   'RMSE': 342.44427502413765,
#   'Predicted': array([-391.1, -395.7, -393.8, 1863.7, -395.7,  178.7, -387.5,  311.4,
#           317.1, -231.3]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  28: {'model': LinearRegression(),
#   'score': 0.8088452150980774,
#   'RMSE': 372.5072465718446,
#   'Predicted': array([-365. , -380.8, -385.6, 1727.6, -377.3,   94.9, -369. ,  538.2,
#           104. , -144. ]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  29: {'model': LinearRegression(),
#   'score': 0.6126907519069092,
#   'RMSE': 378.2255553958015,
#   'Predicted': array([-105.5, -108.4, -109.6, 1009.4, -108.6,   58.6, -104. ,  239.6,
#             6. ,  -77.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  3: {'model': LinearRegression(),
#   'score': 0.8168963358049783,
#   'RMSE': 918.3574890735571,
#   'Predicted': array([-1158.7, -1167.5, -1164.3,  5212.9, -1167.6,   -80. , -1142.7,
#            669.8,   675.9,  -997.6]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  30: {'model': LinearRegression(),
#   'score': 0.8283421602688092,
#   'RMSE': 144.00673610524538,
#   'Predicted': array([-138.8, -145.8, -167.8,  736.8, -120.4,   24.4, -141.6,  310. ,
#            31.5,  -72.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  31: {'model': LinearRegression(),
#   'score': 0.8385989422580575,
#   'RMSE': 335.2758744832502,
#   'Predicted': array([-3.9800e+02, -4.0570e+02, -4.0540e+02,  1.3094e+03, -4.0310e+02,
#           7.0000e-01, -4.0230e+02,  7.6860e+02,  7.2200e+01, -2.1820e+02]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  32: {'model': LinearRegression(),
#   'score': 0.6935496224644905,
#   'RMSE': 184.89633981750666,
#   'Predicted': array([-144. , -146.1, -145.9,  408.9, -145.8,  -72.3, -143.7,  269. ,
#           -49.6,  -73.4]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  33: {'model': LinearRegression(),
#   'score': 0.8573073064018308,
#   'RMSE': 242.606965162264,
#   'Predicted': array([-345.4, -352.7, -352.6,  952.7, -352.7, -105.1, -348.2,  669.9,
#           -22.1, -190.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  34: {'model': LinearRegression(),
#   'score': 0.9048688362789156,
#   'RMSE': 244.1513472968514,
#   'Predicted': array([-392.1, -396. , -393.9, 1800.1, -395.2,  255.9, -389.1,  482.1,
#           116.4, -178.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  35: {'model': LinearRegression(),
#   'score': 0.5732925631219945,
#   'RMSE': 307.0841481178717,
#   'Predicted': array([-178.2, -182.3, -182.3,  886. , -182.4, -107.7, -181. ,  254.8,
#           -59.9, -119.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  36: {'model': LinearRegression(),
#   'score': 0.8122216307575814,
#   'RMSE': 320.50158701013083,
#   'Predicted': array([-296.4, -299.7, -299.6, 1549.1, -299.5,   77.1, -294.9,  421.6,
#            60. , -182.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  37: {'model': LinearRegression(),
#   'score': 0.8561748641898081,
#   'RMSE': 320.1542558495527,
#   'Predicted': array([-408.6, -412.4, -410.3, 1545. , -412.5,  109.5, -405.9,  559.6,
#           399.6, -336.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  38: {'model': LinearRegression(),
#   'score': 0.819717417441071,
#   'RMSE': 356.01619961684116,
#   'Predicted': array([-426.1, -446.2, -452.9, 1264. , -455.9,   60.4, -439.1,  548.2,
#           301.9, -344.6]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  39: {'model': LinearRegression(),
#   'score': 0.7235553402270412,
#   'RMSE': 530.9811998982551,
#   'Predicted': array([-453. , -460.3, -458.8, 1691.6, -460.5,  171. , -454.1,  735.4,
#           -97.6, -357.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  4: {'model': LinearRegression(),
#   'score': 0.8326042315956907,
#   'RMSE': 327.77086974529226,
#   'Predicted': array([-437.1, -441.1, -438.5, 1615.2, -440.7,  -57.3, -435.1,  369.5,
#           279.8, -298.4]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  40: {'model': LinearRegression(),
#   'score': 0.865802180766633,
#   'RMSE': 339.09448603279947,
#   'Predicted': array([-382.3, -381.6, -385. , 1784.8, -384.9,  -95.6, -382.8,  874.9,
#           -78.8, -238.2]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  41: {'model': LinearRegression(),
#   'score': 0.8180091400394109,
#   'RMSE': 285.01840252993856,
#   'Predicted': array([-322.9, -327. , -326.6, 1072.9, -328.5,   67.2, -322.4,  455.1,
#           160.3, -209. ]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  42: {'model': LinearRegression(),
#   'score': 0.6015621553735886,
#   'RMSE': 368.32461403077366,
#   'Predicted': array([ -80.5, -102.5,  -92.3,  805.2,  -92.1,   90.2,  -83.2,  144.3,
#           151.2, -113.7]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  43: {'model': LinearRegression(),
#   'score': 0.8787442829721128,
#   'RMSE': 283.61498208638005,
#   'Predicted': array([-354.6, -360.8, -360.5, 2520.7, -360.8, -117.2, -355.8,  572. ,
#          -112.5, -201.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  44: {'model': LinearRegression(),
#   'score': 0.7913404555595868,
#   'RMSE': 1226.6063004205212,
#   'Predicted': array([-1335.8, -1348.8, -1344.6,  6172.7, -1346.4,   -39.1, -1329.2,
#            926.5,   954.4, -1027.4]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  45: {'model': LinearRegression(),
#   'score': 0.8035824217828859,
#   'RMSE': 1056.6984445980524,
#   'Predicted': array([-1269.7, -1276.8, -1276.1,  5090.6, -1276.7,  -207.4, -1259.5,
#            982.3,   626.9,  -863.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  46: {'model': LinearRegression(),
#   'score': 0.8148968788415808,
#   'RMSE': 812.7142797842257,
#   'Predicted': array([ -973.2, -1001.2,  -998.2,  3481. ,  -987.7,  -264.5,  -997.6,
#           1152.7,   308.9,  -372.8]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  47: {'model': LinearRegression(),
#   'score': 0.8221989021965216,
#   'RMSE': 937.0640589444415,
#   'Predicted': array([ -968.4, -1071. , -1005.3,  4931.2, -1052.8,   -35.9, -1018.4,
#           1046.1,   783.6,  -633.9]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  48: {'model': LinearRegression(),
#   'score': 0.8019035431938513,
#   'RMSE': 742.6070923431771,
#   'Predicted': array([-808.7, -842.8, -837.1, 2732.7, -821.7, -166.6, -824.6, 1184.9,
#           255.4, -295.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  49: {'model': LinearRegression(),
#   'score': 0.7945579083477313,
#   'RMSE': 860.2118552491589,
#   'Predicted': array([-898.2, -921.7, -910.3, 4167.7, -901.1,   63.4, -900.2,  522.8,
#           772.9, -790.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  5: {'model': LinearRegression(),
#   'score': 0.8825134974105817,
#   'RMSE': 223.68108619536545,
#   'Predicted': array([-297.6, -315.6, -322.9, 1140.3, -319.9,   53.2, -317.3,  639.9,
#           165. ,  -92.8]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  50: {'model': LinearRegression(),
#   'score': 0.8600389999040232,
#   'RMSE': 479.1894751425368,
#   'Predicted': array([-663.9, -660.4, -651.7, 2419.3, -668.1, -122.3, -639.6,  836.1,
#           262. , -303.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  51: {'model': LinearRegression(),
#   'score': 0.8274000289254606,
#   'RMSE': 561.7723198780617,
#   'Predicted': array([-718.7, -723.5, -723.8, 3103.1, -721.7,   84. , -716.3,  575.6,
#           598. , -598.5]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  52: {'model': LinearRegression(),
#   'score': 0.582673085892119,
#   'RMSE': 290.12988412300575,
#   'Predicted': array([-14.9, -13.4, -13.9, 202.1, -12.2,  26.2, -11.4,  -9.4, -28.5,
#          -47.8]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  53: {'model': LinearRegression(),
#   'score': 0.6532190482613319,
#   'RMSE': 353.58164842382405,
#   'Predicted': array([-222.5, -228.4, -224.3,  879.9, -224.5,   56.7, -221.2,  306. ,
#            44.6, -143.1]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  54: {'model': LinearRegression(),
#   'score': 0.8065891810102026,
#   'RMSE': 256.05075519943284,
#   'Predicted': array([-271. , -276.2, -275.8,  965.4, -276. ,  -74.8, -273.4,  721. ,
#          -123.6, -115.6]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  6: {'model': LinearRegression(),
#   'score': 0.8445851548277655,
#   'RMSE': 422.74479079747687,
#   'Predicted': array([-581.7, -595.9, -602.8, 2250.2, -599.4,  -82. , -589.6,  538.2,
#           270.9, -353.6]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  7: {'model': LinearRegression(),
#   'score': 0.8061258112131052,
#   'RMSE': 501.8208001959751,
#   'Predicted': array([-586.8, -586. , -583.7, 2514.8, -583.5,   18.7, -580.5,  334.8,
#           524.3, -534.7]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  8: {'model': LinearRegression(),
#   'score': 0.8176566149409501,
#   'RMSE': 544.6226162080353,
#   'Predicted': array([-7.104e+02, -7.154e+02, -7.109e+02,  2.840e+03, -7.149e+02,
#          -5.000e-01, -7.022e+02,  4.207e+02,  5.742e+02, -5.736e+02]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')},
#  9: {'model': LinearRegression(),
#   'score': 0.8492005806306657,
#   'RMSE': 493.0260949907058,
#   'Predicted': array([-623.2, -636.9, -633. , 1993.7, -636.5, -144.8, -626.1,  990.8,
#           -28.2, -140. ]),
#   'Real': date
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   2013-01-01    0.0
#   Name: sales, dtype: float64,
#   'Transformer': MinMaxScaler(),
#   'Encoder': OneHotEncoder(drop='first')}}

# %%
def make_predict(row):
    store_nbr = row['store_nbr']
    transformer = results[store_nbr]['Transformer']
    encoder = results[store_nbr]['Encoder']
    model = results[store_nbr]['model']
    row = pd.DataFrame(row).T
    row=row.astype({'onpromotion':int,'population':int, 'oil_price': float, 'transactions': float})

    # Numerical-Categorical Split
    model_train_num = row.select_dtypes(include = np.number)
    model_train_cat = row.select_dtypes(object)
    
    # Scaling numerical data
    model_train_scaled1 = pd.DataFrame(transformer.transform(model_train_num),columns=model_train_num.columns)

    # Encoding categorical data
    column_names = encoder.get_feature_names_out(model_train_cat.columns)
    model_train_encoded = encoder.transform(model_train_cat).toarray()
    encoded = pd.DataFrame(model_train_encoded, columns =column_names)

    # Concatenate data
    model_train_scaled = pd.concat([model_train_scaled1,encoded],axis=1)
    sales = model.predict(model_train_scaled)
    
    return sales[0]

# %%
one_try = model_train.drop(['sales'], axis=1)
one_try = one_try[:10]

# %%
predictions = one_try.apply(make_predict, axis=1)

# %%
predictions
# Out:
# date
# 2013-01-01    -283.640196
# 2013-01-01    -283.500114
# 2013-01-01    -276.598614
# 2013-01-01    1175.400826
# 2013-01-01    -290.909443
# 2013-01-01      33.960530
# 2013-01-01    -278.890196
# 2013-01-01     283.859804
# 2013-01-01     267.859804
# 2013-01-01    -233.890196
# dtype: float64

# %% [markdown]
# # I will make it for test now

# %%
model_train = merge_data(test)

# %%
test= cleaning_population_data(population_data)
# Out:
# C:\Users\gorka\AppData\Local\Temp\ipykernel_11348\1349901536.py:6: FutureWarning:
#
# The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.

# %%
test= create_columns (test)

# %%
test
# Out:
#            store_nbr                      family  onpromotion   city  \
# date
# 2017-08-16         1                  AUTOMOTIVE            0  quito
# 2017-08-16         1                   BABY CARE            0  quito
# 2017-08-16         1                      BEAUTY            2  quito
# 2017-08-16         1                   BEVERAGES           20  quito
# 2017-08-16         1                       BOOKS            0  quito
# ...              ...                         ...          ...    ...
# 2017-08-31         9                     POULTRY            1  quito
# 2017-08-31         9              PREPARED FOODS            0  quito
# 2017-08-31         9                     PRODUCE            1  quito
# 2017-08-31         9  SCHOOL AND OFFICE SUPPLIES            9  quito
# 2017-08-31         9                     SEAFOOD            0  quito
#
#                 state shop_type cluster  oil_price  transactions holiday_type  \
# date
# 2017-08-16  Pichincha         D      13      46.80           0.0     Work Day
# 2017-08-16  Pichincha         D      13      46.80           0.0     Work Day
# 2017-08-16  Pichincha         D      13      46.80           0.0     Work Day
# 2017-08-16  Pichincha         D      13      46.80           0.0     Work Day
# 2017-08-16  Pichincha         D      13      46.80           0.0     Work Day
# ...               ...       ...     ...        ...           ...          ...
# 2017-08-31  Pichincha         B       6      47.26           0.0     Work Day
# 2017-08-31  Pichincha         B       6      47.26           0.0     Work Day
# 2017-08-31  Pichincha         B       6      47.26           0.0     Work Day
# 2017-08-31  Pichincha         B       6      47.26           0.0     Work Day
# 2017-08-31  Pichincha         B       6      47.26           0.0     Work Day
#
#             population month day_of_month day_of_year week_of_year  \
# date
# 2017-08-16     1607734     8           16         228           33
# 2017-08-16     1607734     8           16         228           33
# 2017-08-16     1607734     8           16         228           33
# 2017-08-16     1607734     8           16         228           33
# 2017-08-16     1607734     8           16         228           33
# ...                ...   ...          ...         ...          ...
# 2017-08-31     1607734     8           31         243           35
# 2017-08-31     1607734     8           31         243           35
# 2017-08-31     1607734     8           31         243           35
# 2017-08-31     1607734     8           31         243           35
# 2017-08-31     1607734     8           31         243           35
#
#            day_of_week  year is_wknd
# date
# 2017-08-16           3  2017       0
# 2017-08-16           3  2017       0
# 2017-08-16           3  2017       0
# 2017-08-16           3  2017       0
# 2017-08-16           3  2017       0
# ...                ...   ...     ...
# 2017-08-31           4  2017       0
# 2017-08-31           4  2017       0
# 2017-08-31           4  2017       0
# 2017-08-31           4  2017       0
# 2017-08-31           4  2017       0
#
# [28512 rows x 18 columns]

# %%
predictions = test.apply(make_predict, axis=1)

# %%
predictions = pd.DataFrame(predictions).reset_index()
predictions
# Out:
#             date            0
# 0     2017-08-16  -140.152611
# 1     2017-08-16  -140.027611
# 2     2017-08-16  -108.715111
# 3     2017-08-16  1562.909889
# 4     2017-08-16  -147.402611
# ...          ...          ...
# 28507 2017-08-31   155.487196
# 28508 2017-08-31  -235.823463
# 28509 2017-08-31   535.612196
# 28510 2017-08-31  -216.308778
# 28511 2017-08-31  -302.616432
#
# [28512 rows x 2 columns]

# %%
sample_submission1 = pd.concat ([sample_submission,predictions], axis=1)

# %%
sample_submission1=sample_submission1.drop(['sales','date'], axis=1)

# %%
sample_submission1 = sample_submission1.rename(columns={0: 'sales'})

# %%
# sample_submission1.loc[sample_submission1['sales'] < 0, 'sales'] = 0

# %%
sample_submission1.to_csv("sample_submission1.csv", index=False)

# %%
sample_submission1
# Out:
#             id        sales
# 0      3000888  -140.152611
# 1      3000889  -140.027611
# 2      3000890  -108.715111
# 3      3000891  1562.909889
# 4      3000892  -147.402611
# ...        ...          ...
# 28507  3029395   155.487196
# 28508  3029396  -235.823463
# 28509  3029397   535.612196
# 28510  3029398  -216.308778
# 28511  3029399  -302.616432
#
# [28512 rows x 2 columns]
